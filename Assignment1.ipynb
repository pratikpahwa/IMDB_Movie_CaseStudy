# %%
import numpy as np
import pandas as pd

# %%
movies1 = pd.read_csv("C:/Users/pratik.pahwa/Desktop/Pratik Learning/Assignment/Movie+Assignment+Data - Copy.csv")
movies1
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
#movies.shape
#movies.info()
#movies.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4993.000000  5028.000000              4939.000000
# mean               140.194272   107.201074               686.509212
# std                121.601675    25.197441              2813.328607
# min                  1.000000     7.000000                 0.000000
# 25%                 50.000000    93.000000                 7.000000
# 50%                110.000000   103.000000                49.000000
# 75%                195.000000   118.000000               194.500000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             5020.000000             5036.000000  4.159000e+03
# mean               645.009761             6560.047061  4.846841e+07
# std               1665.041728            15020.759120  6.845299e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %%
# Write your code for column-wise null count here
movies1.isnull().sum(axis=0)
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
# Write your code for row-wise null count here
movies1.isnull().sum(axis=1)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4       14
#         ..
# 5038     4
# 5039     5
# 5040     4
# 5041     2
# 5042     0
# Length: 5043, dtype: int64

# %%
# Write your code for column-wise null percentages here
round((movies1.isnull().sum(axis=0)/len(movies1.index))*100,2)
# Out:
# color                         0.38
# director_name                 2.06
# num_critic_for_reviews        0.99
# duration                      0.30
# director_facebook_likes       2.06
# actor_3_facebook_likes        0.46
# actor_2_name                  0.26
# actor_1_facebook_likes        0.14
# gross                        17.53
# genres                        0.00
# actor_1_name                  0.14
# movie_title                   0.00
# num_voted_users               0.00
# cast_total_facebook_likes     0.00
# actor_3_name                  0.46
# facenumber_in_poster          0.26
# plot_keywords                 3.03
# movie_imdb_link               0.00
# num_user_for_reviews          0.42
# language                      0.24
# country                       0.10
# content_rating                6.01
# budget                        9.76
# title_year                    2.14
# actor_2_facebook_likes        0.26
# imdb_score                    0.00
# aspect_ratio                  6.52
# ...

# %%
# Write your code for dropping the columns here. It is advised to keep inspecting the dataframe after each set of operations 
movies1 = movies1.drop("color",axis=1)
movies1 = movies1.drop("director_facebook_likes",axis=1)
movies1 = movies1.drop("actor_1_facebook_likes",axis=1)
movies1 = movies1.drop("actor_2_facebook_likes",axis=1)
movies1 = movies1.drop("actor_3_facebook_likes",axis=1)
movies1 = movies1.drop("actor_2_name",axis=1)
movies1 = movies1.drop("cast_total_facebook_likes",axis=1)
movies1 = movies1.drop("actor_3_name",axis=1)
movies1 = movies1.drop("duration",axis=1)
movies1 = movies1.drop("facenumber_in_poster",axis=1)
movies1 = movies1.drop("content_rating",axis=1)
movies1 = movies1.drop("country",axis=1)
movies1 = movies1.drop("movie_imdb_link",axis=1)
movies1 = movies1.drop("aspect_ratio",axis=1)
movies1 = movies1.drop("plot_keywords",axis=1)

# %%
movies1
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 4           Doug Walker                     NaN          NaN
# ...                 ...                     ...          ...
# 5038        Scott Smith                     1.0          NaN
# 5039                NaN                    43.0          NaN
# 5040   Benjamin Roberds                    13.0          NaN
# 5041        Daniel Hsia                    14.0      10443.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                genres     actor_1_name  \
# 0     Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1            Action|Adventure|Fantasy      Johnny Depp
# 2           Action|Adventure|Thriller  Christoph Waltz
# ...

# %%
# Write your code for dropping the rows here
#(movies1.isnull().sum(axis=0)/len(movies1.index)*100)>5
#output generated is gross and budget
movies1 = movies1[~np.isnan(movies1['gross'])]
#movies1 = movies1[~np.isnan(movies1['budget'])]

# %%
(movies1.isnull().sum(axis=0)/len(movies1.index)*100)
# Out:
# director_name             0.000000
# num_critic_for_reviews    0.025700
# gross                     0.000000
# genres                    0.000000
# actor_1_name              0.077101
# movie_title               0.000000
# num_voted_users           0.000000
# num_user_for_reviews      0.000000
# language                  0.077101
# budget                    0.000000
# title_year                0.000000
# imdb_score                0.000000
# movie_facebook_likes      0.000000
# dtype: float64

# %%
# Write your code for dropping the rows here
(movies1.isnull().sum(axis=0)/len(movies1.index)*100)>5
#output generated is gross and budget so we will remove null values from gross and budget column
#movies1 = movies1[~np.isnan(movies1['gross'])]
movies1 = movies1[~np.isnan(movies1['budget'])]

# %%
# Write your code for dropping the rows here
movies1 = movies1[movies1.isnull().sum(axis=1)<=5]

# %%
# Write your code for filling the NaN values in the 'language' column here
movies1.loc[pd.isnull(movies1['language']),['language']] = 'English'

# %%
# Write your code for checking number of retained rows here
#movies.isnull().sum()
#len(movies.index)
len(movies1.index)/5044
# Out:
# 0.7714115781126091

# %%
movies1
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 5        Andrew Stanton                   462.0   73058679.0
# ...                 ...                     ...          ...
# 5033      Shane Carruth                   143.0     424760.0
# 5034   Neill Dela Llana                    35.0      70071.0
# 5035   Robert Rodriguez                    56.0    2040920.0
# 5037       Edward Burns                    14.0       4584.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# ...

# %%
movies1[['budget', 'gross']] = movies1[['budget', 'gross']].apply(lambda x : x/1000000)
#movies1[['budget']] = movies1[['budget']].apply(lambda x : x/1000000)

#movies1['gross'] = movies1['gross']/10**6
#movies1['budget'] = movies1['budget']/10**6

# %%
movies1
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 1        Gore Verbinski                   302.0  309.404152
# 2            Sam Mendes                   602.0  200.074175
# 3     Christopher Nolan                   813.0  448.130642
# 5        Andrew Stanton                   462.0   73.058679
# ...                 ...                     ...         ...
# 5033      Shane Carruth                   143.0    0.424760
# 5034   Neill Dela Llana                    35.0    0.070071
# 5035   Robert Rodriguez                    56.0    2.040920
# 5037       Edward Burns                    14.0    0.004584
# 5042           Jon Gunn                    43.0    0.085222
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# 2               Action|Adventure|Thriller  Christoph Waltz
# ...

# %%
movies1['profit'] = movies1.gross-movies1.budget

# %%
movies1.sort_values(by = "profit", ascending= True)
# Out:
#           director_name  num_critic_for_reviews     gross  \
# 2988       Joon-ho Bong                   363.0  2.201412
# 3859     Chan-wook Park                   202.0  0.211667
# 3005       Lajos Koltai                    73.0  0.195888
# 2323     Hayao Miyazaki                   174.0  2.298191
# 2334    Katsuhiro Ôtomo                   105.0  0.410388
# ...                 ...                     ...       ...
# 5033      Shane Carruth                   143.0  0.424760
# 5035   Robert Rodriguez                    56.0  2.040920
# 5026    Olivier Assayas                    81.0  0.136007
# 5042           Jon Gunn                    43.0  0.085222
# 4799  Jonathan Caouette                    72.0  0.592014
#
#                                                  genres      actor_1_name  \
# 2988                         Comedy|Drama|Horror|Sci-Fi         Doona Bae
# 3859                                        Crime|Drama      Min-sik Choi
# ...

# %%
#Plot profit (y-axis) vs budget (x- axis) and observe the outliers using the appropriate chart type
import seaborn as sns
sns.jointplot('budget','profit', movies1)

# %%
top10_1 = movies1.sort_values(by = "profit", ascending= False).head(10)

# %%
top10_1
# Out:
#           director_name  num_critic_for_reviews     gross  \
# 4799  Jonathan Caouette                    72.0  0.592014
# 5042           Jon Gunn                    43.0  0.085222
# 5026    Olivier Assayas                    81.0  0.136007
# 5035   Robert Rodriguez                    56.0  2.040920
# 5033      Shane Carruth                   143.0  0.424760
# 5034   Neill Dela Llana                    35.0  0.070071
# 5037       Edward Burns                    14.0  0.004584
# 5027       Jafar Panahi                    64.0  0.673780
# 5025        John Waters                    73.0  0.180483
# 4311    Hunter Richards                    34.0  0.012667
#
#                                    genres             actor_1_name  \
# 4799                Biography|Documentary               Greg Ayres
# 5042                          Documentary              John August
# 5026                  Drama|Music|Romance            Maggie Cheung
# ...

# %%
movies1.info
# Out:
# <bound method DataFrame.info of           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 1        Gore Verbinski                   302.0  309.404152
# 2            Sam Mendes                   602.0  200.074175
# 3     Christopher Nolan                   813.0  448.130642
# 5        Andrew Stanton                   462.0   73.058679
# ...                 ...                     ...         ...
# 5033      Shane Carruth                   143.0    0.424760
# 5034   Neill Dela Llana                    35.0    0.070071
# 5035   Robert Rodriguez                    56.0    2.040920
# 5037       Edward Burns                    14.0    0.004584
# 5042           Jon Gunn                    43.0    0.085222
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# ...

# %%
movies1.drop_duplicates(keep = 'first', inplace = True)

# %%
movies1.info
# Out:
# <bound method DataFrame.info of           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 1        Gore Verbinski                   302.0  309.404152
# 2            Sam Mendes                   602.0  200.074175
# 3     Christopher Nolan                   813.0  448.130642
# 5        Andrew Stanton                   462.0   73.058679
# ...                 ...                     ...         ...
# 5033      Shane Carruth                   143.0    0.424760
# 5034   Neill Dela Llana                    35.0    0.070071
# 5035   Robert Rodriguez                    56.0    2.040920
# 5037       Edward Burns                    14.0    0.004584
# 5042           Jon Gunn                    43.0    0.085222
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# ...

# %%
movies1
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 1        Gore Verbinski                   302.0  309.404152
# 2            Sam Mendes                   602.0  200.074175
# 3     Christopher Nolan                   813.0  448.130642
# 5        Andrew Stanton                   462.0   73.058679
# ...                 ...                     ...         ...
# 5033      Shane Carruth                   143.0    0.424760
# 5034   Neill Dela Llana                    35.0    0.070071
# 5035   Robert Rodriguez                    56.0    2.040920
# 5037       Edward Burns                    14.0    0.004584
# 5042           Jon Gunn                    43.0    0.085222
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# 2               Action|Adventure|Thriller  Christoph Waltz
# ...

# %%
# Write your code for sorting the dataframe here
movies1.sort_values(by = "profit", ascending= True)
# Out:
#           director_name  num_critic_for_reviews     gross  \
# 2988       Joon-ho Bong                   363.0  2.201412
# 3859     Chan-wook Park                   202.0  0.211667
# 3005       Lajos Koltai                    73.0  0.195888
# 2323     Hayao Miyazaki                   174.0  2.298191
# 2334    Katsuhiro Ôtomo                   105.0  0.410388
# ...                 ...                     ...       ...
# 5033      Shane Carruth                   143.0  0.424760
# 5035   Robert Rodriguez                    56.0  2.040920
# 5026    Olivier Assayas                    81.0  0.136007
# 5042           Jon Gunn                    43.0  0.085222
# 4799  Jonathan Caouette                    72.0  0.592014
#
#                                                  genres      actor_1_name  \
# 2988                         Comedy|Drama|Horror|Sci-Fi         Doona Bae
# 3859                                        Crime|Drama      Min-sik Choi
# ...

# %%
top10_2 = movies1.sort_values(by = "profit", ascending= False).head(10)
# Write your code to get the top 10 profiting movies here

# %%
top10_2
# Out:
#           director_name  num_critic_for_reviews     gross  \
# 4799  Jonathan Caouette                    72.0  0.592014
# 5042           Jon Gunn                    43.0  0.085222
# 5026    Olivier Assayas                    81.0  0.136007
# 5035   Robert Rodriguez                    56.0  2.040920
# 5033      Shane Carruth                   143.0  0.424760
# 5034   Neill Dela Llana                    35.0  0.070071
# 5037       Edward Burns                    14.0  0.004584
# 5027       Jafar Panahi                    64.0  0.673780
# 5025        John Waters                    73.0  0.180483
# 4311    Hunter Richards                    34.0  0.012667
#
#                                    genres             actor_1_name  \
# 4799                Biography|Documentary               Greg Ayres
# 5042                          Documentary              John August
# 5026                  Drama|Music|Romance            Maggie Cheung
# ...

# %%
movies1
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 1        Gore Verbinski                   302.0  309.404152
# 2            Sam Mendes                   602.0  200.074175
# 3     Christopher Nolan                   813.0  448.130642
# 5        Andrew Stanton                   462.0   73.058679
# ...                 ...                     ...         ...
# 5033      Shane Carruth                   143.0    0.424760
# 5034   Neill Dela Llana                    35.0    0.070071
# 5035   Robert Rodriguez                    56.0    2.040920
# 5037       Edward Burns                    14.0    0.004584
# 5042           Jon Gunn                    43.0    0.085222
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# 2               Action|Adventure|Thriller  Christoph Waltz
# ...

# %%
#num_voted_users>25000
#imdb score top 250
#Add Rank column
Top_250_1 = movies1[movies1.num_voted_users>25000].sort_values(by = "imdb_score", ascending = False).head(250)
#movies1.sort_values(by = "profit", ascending= False).head(10)

# %%
Top_250_1
# Out:
#              director_name  num_critic_for_reviews       gross  \
# 1937        Frank Darabont                   199.0   28.341469
# 3466  Francis Ford Coppola                   208.0  134.821952
# 2837  Francis Ford Coppola                   149.0   57.300000
# 66       Christopher Nolan                   645.0  533.316061
# 4498          Sergio Leone                   181.0    6.100000
# ...                    ...                     ...         ...
# 4931           John Carney                   232.0    9.437933
# 2605               Ang Lee                   287.0  128.067808
# 3029      David O. Russell                   410.0   93.571803
# 2177            Tim Burton                   111.0   56.362352
# 2487          George Cukor                    82.0   72.000000
#
#                             genres    actor_1_name  \
# 1937                   Crime|Drama  Morgan Freeman
# 3466                   Crime|Drama       Al Pacino
# 2837                   Crime|Drama  Robert De Niro
# ...

# %%
Top_250_1['Rank'] = Top_250_1.imdb_score.rank(ascending = False ,method ='first')

# %%
Top_250_1
# Out:
#              director_name  num_critic_for_reviews       gross  \
# 1937        Frank Darabont                   199.0   28.341469
# 3466  Francis Ford Coppola                   208.0  134.821952
# 2837  Francis Ford Coppola                   149.0   57.300000
# 66       Christopher Nolan                   645.0  533.316061
# 4498          Sergio Leone                   181.0    6.100000
# ...                    ...                     ...         ...
# 4931           John Carney                   232.0    9.437933
# 2605               Ang Lee                   287.0  128.067808
# 3029      David O. Russell                   410.0   93.571803
# 2177            Tim Burton                   111.0   56.362352
# 2487          George Cukor                    82.0   72.000000
#
#                             genres    actor_1_name  \
# 1937                   Crime|Drama  Morgan Freeman
# 3466                   Crime|Drama       Al Pacino
# 2837                   Crime|Drama  Robert De Niro
# ...

# %%
Top_Foreign_Lang_Film_1 = Top_250_1[Top_250_1.language!='English']

# %%
Top_Foreign_Lang_Film_1
# Out:
#                          director_name  num_critic_for_reviews       gross  \
# 4498                      Sergio Leone                   181.0    6.100000
# 4747                    Akira Kurosawa                   153.0    0.269061
# 4029                Fernando Meirelles                   214.0    7.563397
# 2373                    Hayao Miyazaki                   246.0   10.049886
# 4259  Florian Henckel von Donnersmarck                   215.0   11.284657
# 4921                      Majid Majidi                    46.0    0.925402
# 2323                    Hayao Miyazaki                   174.0    2.298191
# 2970                 Wolfgang Petersen                    96.0   11.433134
# 4105                    Chan-wook Park                   305.0    2.181290
# 4659                    Asghar Farhadi                   354.0    7.098492
# 1329                    S.S. Rajamouli                    44.0    6.498000
# ...

# %%
movies1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3856 entries, 0 to 5042
# Data columns (total 14 columns):
# director_name             3856 non-null object
# num_critic_for_reviews    3855 non-null float64
# gross                     3856 non-null float64
# genres                    3856 non-null object
# actor_1_name              3853 non-null object
# movie_title               3856 non-null object
# num_voted_users           3856 non-null int64
# num_user_for_reviews      3856 non-null float64
# language                  3856 non-null object
# budget                    3856 non-null float64
# title_year                3856 non-null float64
# imdb_score                3856 non-null float64
# movie_facebook_likes      3856 non-null int64
# profit                    3856 non-null float64
# dtypes: float64(7), int64(2), object(5)
# memory usage: 451.9+ KB

# %%
#Group the dataframe using the director_name column.
director_group = movies1.groupby("director_name")

# %%
#Find out the top 10 directors for whom the mean of imdb_score is the highest and store them in a new dataframe top10director
top10director_1 = director_group.imdb_score.mean().sort_values(ascending = False).head(10)

# %%
top10director_1
# Out:
# director_name
# Charles Chaplin      8.600000
# Tony Kaye            8.600000
# Ron Fricke           8.500000
# Damien Chazelle      8.500000
# Majid Majidi         8.500000
# Alfred Hitchcock     8.500000
# Sergio Leone         8.433333
# Christopher Nolan    8.425000
# Asghar Farhadi       8.400000
# Richard Marquand     8.400000
# Name: imdb_score, dtype: float64

# %%
movies1
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 1        Gore Verbinski                   302.0  309.404152
# 2            Sam Mendes                   602.0  200.074175
# 3     Christopher Nolan                   813.0  448.130642
# 5        Andrew Stanton                   462.0   73.058679
# ...                 ...                     ...         ...
# 5033      Shane Carruth                   143.0    0.424760
# 5034   Neill Dela Llana                    35.0    0.070071
# 5035   Robert Rodriguez                    56.0    2.040920
# 5037       Edward Burns                    14.0    0.004584
# 5042           Jon Gunn                    43.0    0.085222
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# 2               Action|Adventure|Thriller  Christoph Waltz
# ...

# %%
movies1["genres"]
# Out:
# 0           Action|Adventure|Fantasy|Sci-Fi
# 1                  Action|Adventure|Fantasy
# 2                 Action|Adventure|Thriller
# 3                           Action|Thriller
# 5                   Action|Adventure|Sci-Fi
#                        ...
# 5033                  Drama|Sci-Fi|Thriller
# 5034                               Thriller
# 5035    Action|Crime|Drama|Romance|Thriller
# 5037                           Comedy|Drama
# 5042                            Documentary
# Name: genres, Length: 3856, dtype: object

# %%
#Extract the first two genres from the genres column and store them in two new columns: genre_1 and genre_2. Some of the movies might have only one genre. In such cases,
#    extract the single genre into both the columns, i.e. for such movies the genre_2 will be the same as genre_1.
movies1["genre1_1"] = movies1['genres'].apply(lambda x : x.split('|')[0])

# %%
movies1["genre1_1"]
# Out:
# 0            Action
# 1            Action
# 2            Action
# 3            Action
# 5            Action
#            ...
# 5033          Drama
# 5034       Thriller
# 5035         Action
# 5037         Comedy
# 5042    Documentary
# Name: genre1_1, Length: 3856, dtype: object

# %%
movies1["genre1_2"] = movies1["genres"].apply(lambda x: x.split('|')[0] if len(x.split('|')) ==1 else x.split('|')[1])

# %%
movies1[["genres","genre1_1","genre1_2"]]
# Out:
#                                    genres     genre1_1     genre1_2
# 0         Action|Adventure|Fantasy|Sci-Fi       Action    Adventure
# 1                Action|Adventure|Fantasy       Action    Adventure
# 2               Action|Adventure|Thriller       Action    Adventure
# 3                         Action|Thriller       Action     Thriller
# 5                 Action|Adventure|Sci-Fi       Action    Adventure
# ...                                   ...          ...          ...
# 5033                Drama|Sci-Fi|Thriller        Drama       Sci-Fi
# 5034                             Thriller     Thriller     Thriller
# 5035  Action|Crime|Drama|Romance|Thriller       Action        Crime
# 5037                         Comedy|Drama       Comedy        Drama
# 5042                          Documentary  Documentary  Documentary
#
# [3856 rows x 3 columns]

# %%
#Group the dataframe using genre_1 as the primary column and genre_2 as the secondary column.
movie_genre_group = movies1.groupby(["genre1_1","genre1_2"])

# %%
#Find out the 5 most popular combo of genres by finding the mean of the gross values using the gross column and store them in a new dataframe named PopGenre.
PopGenre_1 = movie_genre_group.gross.mean().sort_values(ascending = False).head(5)

# %%
PopGenre_1
# Out:
# genre1_1   genre1_2
# Family     Sci-Fi       434.949459
# Adventure  Sci-Fi       228.627758
#            Family       118.919540
#            Animation    116.998550
# Action     Adventure    109.595465
# Name: gross, dtype: float64

# %%
#Create three new dataframes namely, Meryl_Streep, Leo_Caprio, and Brad_Pitt which contain the movies in which the actors: 'Meryl Streep', 'Leonardo DiCaprio', 
#and 'Brad Pitt' are the lead actors. Use only the actor_1_name column for extraction. 
#Also, make sure that you use the names 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' for the said extraction.

actor_1_cat = ['Meryl Streep']
movies1.loc[movies1["actor_1_name"].isin(actor_1_cat),:]
# Out:
#        director_name  num_critic_for_reviews       gross  \
# 410     Nancy Meyers                   187.0  112.703470
# 1106   Curtis Hanson                    42.0   46.815748
# 1204     Nora Ephron                   252.0   94.125426
# 1408   David Frankel                   208.0  124.732962
# 1483  Robert Redford                   227.0   14.998070
# 1575  Sydney Pollack                    66.0   87.100000
# 1618   David Frankel                   234.0   63.536011
# 1674   Carl Franklin                    64.0   23.209440
# 1925  Stephen Daldry                   174.0   41.597830
# 2781  Phyllida Lloyd                   331.0   29.959436
# 3135   Robert Altman                   211.0   20.338609
#
#                                genres  actor_1_name  \
# 410              Comedy|Drama|Romance  Meryl Streep
# 1106  Action|Adventure|Crime|Thriller  Meryl Streep
# 1204          Biography|Drama|Romance  Meryl Streep
# 1408             Comedy|Drama|Romance  Meryl Streep
# ...

# %%
Meryl_Streep_1 = movies1[movies1.actor_1_name =='Meryl Streep']

# %%
Meryl_Streep_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11 entries, 410 to 3135
# Data columns (total 16 columns):
# director_name             11 non-null object
# num_critic_for_reviews    11 non-null float64
# gross                     11 non-null float64
# genres                    11 non-null object
# actor_1_name              11 non-null object
# movie_title               11 non-null object
# num_voted_users           11 non-null int64
# num_user_for_reviews      11 non-null float64
# language                  11 non-null object
# budget                    11 non-null float64
# title_year                11 non-null float64
# imdb_score                11 non-null float64
# movie_facebook_likes      11 non-null int64
# profit                    11 non-null float64
# genre1_1                  11 non-null object
# genre1_2                  11 non-null object
# dtypes: float64(7), int64(2), object(7)
# memory usage: 1.5+ KB

# %%
Leo_Caprio_1 = movies1[movies1.actor_1_name =='Leonardo DiCaprio']

# %%
Leo_Caprio_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21 entries, 26 to 3476
# Data columns (total 16 columns):
# director_name             21 non-null object
# num_critic_for_reviews    21 non-null float64
# gross                     21 non-null float64
# genres                    21 non-null object
# actor_1_name              21 non-null object
# movie_title               21 non-null object
# num_voted_users           21 non-null int64
# num_user_for_reviews      21 non-null float64
# language                  21 non-null object
# budget                    21 non-null float64
# title_year                21 non-null float64
# imdb_score                21 non-null float64
# movie_facebook_likes      21 non-null int64
# profit                    21 non-null float64
# genre1_1                  21 non-null object
# genre1_2                  21 non-null object
# dtypes: float64(7), int64(2), object(7)
# memory usage: 2.8+ KB

# %%
Brad_Pitt_1 = movies1[movies1.actor_1_name =='Brad Pitt']

# %%
Brad_Pitt_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17 entries, 101 to 2898
# Data columns (total 16 columns):
# director_name             17 non-null object
# num_critic_for_reviews    17 non-null float64
# gross                     17 non-null float64
# genres                    17 non-null object
# actor_1_name              17 non-null object
# movie_title               17 non-null object
# num_voted_users           17 non-null int64
# num_user_for_reviews      17 non-null float64
# language                  17 non-null object
# budget                    17 non-null float64
# title_year                17 non-null float64
# imdb_score                17 non-null float64
# movie_facebook_likes      17 non-null int64
# profit                    17 non-null float64
# genre1_1                  17 non-null object
# genre1_2                  17 non-null object
# dtypes: float64(7), int64(2), object(7)
# memory usage: 2.3+ KB

# %%
#Append the rows of all these dataframes and store them in a new dataframe named Combined.

# %%
combined_1 = Meryl_Streep_1.append(Leo_Caprio_1).append(Brad_Pitt_1)

# %%
combined_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49 entries, 410 to 2898
# Data columns (total 16 columns):
# director_name             49 non-null object
# num_critic_for_reviews    49 non-null float64
# gross                     49 non-null float64
# genres                    49 non-null object
# actor_1_name              49 non-null object
# movie_title               49 non-null object
# num_voted_users           49 non-null int64
# num_user_for_reviews      49 non-null float64
# language                  49 non-null object
# budget                    49 non-null float64
# title_year                49 non-null float64
# imdb_score                49 non-null float64
# movie_facebook_likes      49 non-null int64
# profit                    49 non-null float64
# genre1_1                  49 non-null object
# genre1_2                  49 non-null object
# dtypes: float64(7), int64(2), object(7)
# memory usage: 6.5+ KB

# %%
combined_1_group = combined_1.groupby("actor_1_name")

# %%
# Write the code for finding the mean of critic reviews and audience reviews here

# %%
combined_1_group.num_critic_for_reviews.mean()
# Out:
# actor_1_name
# Brad Pitt            245.000000
# Leonardo DiCaprio    330.190476
# Meryl Streep         181.454545
# Name: num_critic_for_reviews, dtype: float64

# %%
combined_1_group.num_user_for_reviews.mean()
# Out:
# actor_1_name
# Brad Pitt            742.352941
# Leonardo DiCaprio    914.476190
# Meryl Streep         297.181818
# Name: num_user_for_reviews, dtype: float64

# %%
movies1.title_year.head(30)
# Out:
# 0     2009.0
# 1     2007.0
# 2     2015.0
# 3     2012.0
# 5     2012.0
# 6     2007.0
# 7     2010.0
# 8     2015.0
# 9     2009.0
# 10    2016.0
# 11    2006.0
# 12    2008.0
# 13    2006.0
# 14    2013.0
# 15    2013.0
# 16    2008.0
# 17    2012.0
# 18    2011.0
# 19    2012.0
# 20    2014.0
# 21    2012.0
# 22    2010.0
# 23    2013.0
# 24    2007.0
# 25    2005.0
# 26    1997.0
# 27    2016.0
# 28    2012.0
# 29    2015.0
# 30    2012.0
# Name: title_year, dtype: float64

# %%
    5. Observe the change in number of voted users over decades using a bar chart. 
    Create a column called `decade` which represents the decade to which every movie belongs to. 
    For example, the  `title_year`  year 1923, 1925 should be stored as 1920s. 
    Sort the dataframe based on the column `decade`, group it by `decade` and find the sum of users voted in each decade. 
    Store this in a new data frame called `df_by_decade`.

# %%
movies1["decade"] = movies1["title_year"].apply(lambda x : str(int(x//10)*10) + 's')

# %%
decade_group = movies1.groupby("decade")

# %%
df_by_decade1 = pd.DataFrame(decade_group.num_voted_users.sum()).sort_values(by ="decade")

# %%
df_by_decade1.reset_index(inplace = True)

# %%
df_by_decade1
# Out:
#   decade  num_voted_users
# 0  1920s           116392
# 1  1930s           804839
# 2  1940s           230838
# 3  1950s           678336
# 4  1960s          2983442
# 5  1970s          8524102
# 6  1980s         19987476
# 7  1990s         69735679
# 8  2000s        170908676
# 9  2010s        120640994
